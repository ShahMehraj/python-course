# %% [markdown]
# ## Pledge
# 1. Store you first name and last name in two different variables. Then print the following string:
# ```python
# I, {your full name} will not use any external LLM for solving this assignment
# ```

# %% [markdown]
# ## Command Line Interpreter
# 1. Write a command to list all files and directories in the current folder. What will be the output if the current directory is empty?
#
# 3. You need to create a directory named `Assignment` inside the current working directory and then create another directory named `Python` inside `Assignment`. Write the sequence of commands.
#
# 4. You accidentally created a file named `wrong.txt`. Write the command to delete this file.

# %% [markdown]
# ## Variables
# 1. Write a Python program to swap the values of two variables `a` and `b` without using a third variable. Initialize `a = 3` and `b = 7`, and print their values before and after swapping. (Please don't use `a,b = b,a` or any built in python functionality for the same.

# %%
# Write your code here:

# %% [markdown]
# 2. What will be the output of the following code? Explain why. (Please don't run before working out the ouput yourself).
#
#    ```python
#    x = 5
#    y = x
#    x = 10
#    print(y)

# %%
# Write your code/answer here:

# %% [markdown]
# ## Conditionals
#
# 1. Write a program that asks the user for their weight (in kilograms) and height (in meters), calculates the BMI using the formula
#
# $$ \text{BMI} = \frac{\text{weight}}{ \text{height}^2} $$
#
#     and prints whether the person is underweight (BMI < 18.5), normal (18.5 <= BMI <    25), overweight (25 <= BMI < 30), or obese (BMI >= 30).

# %%
# Write your code/answer here:

# %% [markdown]
# 2. Take two integer inputs from the user and print `True` if the first number is greater than the second, otherwise print `False`.

# %%
# Write your code/answer here:

# %% [markdown]
# ## Strings
# 1. Write a Python program that takes a sentence as input and prints the same sentence in reverse word order. For example, input: `"Python is fun"` should output: `"fun is Python"`.

# %%
# Write your code/answer here:

# %% [markdown]
# 2. Given a string `text = "abracadabra"`, write code to:
#    - Count how many times the letter `'a'` appears.
#    - Replace all occurrences of `'a'` with `'*'`.
#    - Check if the word `"cad"` exists in the string and print the result as `True` or `False`.

# %%
# Write your code/answer here:

# %% [markdown]
# ## List
#
# 1. Write a Python program that takes 5 integers as input from the user, stores them in a list, and then:
#    - Prints the list in reverse order.
#    - Prints the sum of all elements.
#    - Prints the maximum and minimum values.

# %%
# Write your code/answer here:

# %% [markdown]
# 2. Given a list `nums = [3, 5, 7, 9, 5, 3, 1, 3]`, write code to:
#    - Remove all occurrences of the number `3`.
#    - Insert the number `10` at the second position.
#    - Sort the list in descending order.

# %%
# Write your code/answer here:

# %% [markdown]
# 3. Write a program that takes a list of words as input and prints a new list containing only the words that have more than 4 characters. Use list comprehension.

# %%
# Write your code/answer here:

# %% [markdown]
# ## Loops
# 1. Write a Python program that prints all prime numbers between 10 and 50 using a loop.

# %%
# Write your code/answer here:

# %% [markdown]
# 2. Create a loop that takes input from the user repeatedly until they type `"exit"`. After each input, print the number of characters in the input.

# %%
# Write your code/answer here:

# %% [markdown]
# 3. Write a code that finds the largest element of a list without using any built in functions.

# %%
# Write your code/answer here:

# %% [markdown]
# ## Dictionary
#
# 1. Create a dictionary that stores the names of 3 students as keys and their marks as values. Write code to:
#    - Print all keys.
#    - Print all values.
#    - Find and print the name of the student with the highest marks.

# %%
# Write your code/answer here:

# %% [markdown]
# 2. You have a dictionary of movies with age ratings. Each rating means a viewer must be at least that age to watch the movie. Write a python script that takes user age and displays the movies they can watch too.
# ```python
# movies = {
#     "The Dark Knight": 16,
#     "Deadpool": 18,
#     "Toy Story": 0,
#     "Avengers: Endgame": 13,
#     "Joker": 18,
#     "Finding Nemo": 0,
#     "Inception": 14,
#     "The Lion King": 0,
#     "Shutter Island": 16,
#     "Spider-Man: No Way Home": 13,
#     "Up": 0,
#     "Interstellar": 12,
#     "The Matrix": 16,
#     "Frozen": 0,
#     "Logan": 18
# }
#
# ```

# %% [markdown]
# 3. Given a dictionary `inventory = {'apple': 10, 'banana': 5, 'orange': 8}`, write a program to:
#    - Add a new item `'grapes': 15`.
#    - Update the quantity of `'banana'` to 12.
#    - Remove `'orange'` from the dictionary.
#    - Print the final dictionary.

# %%
# Write your code/answer here:

# %% [markdown]
# ## Sets and Tuples
# 1. Create two sets: `set1 = {1, 2, 3, 4}` and `set2 = {3, 4, 5, 6}`. Write a Python program to:
#    - Find the union of the sets.
#    - Find their intersection.
#    - Find elements that are in `set1` but not in `set2`.

# %%
# Write your code/answer here:

# %% [markdown]
# 2. Given a tuple `t = (10, 20, 30, 40, 50)`, write code to:
#    - Print the first and last elements.
#    - Reverse the tuple.
#    - Check if the number `25` exists in the tuple.

# %%
# Write your code/answer here:

# %% [markdown]
# 3. Take a list of integers from the user and convert it into a tuple. Then, create a set from that tuple and print the number of unique elements.

# %%
# Write your code/answer here:

# %% [markdown]
# ## File Handling
# 1. Using the `mailbox.txt` file, write a Python program to read the file and print the subject lines of all emails received from `you@example.com`.

# %%
# Write your code/answer here:

# %% [markdown]
# 2. Write a program that reads `mailbox.txt` and counts how many different people sent emails. Ignore duplicates and print the count along with the unique sender email addresses.

# %%
# Write your code/answer here:

# %% [markdown]
# ## Functions
# 1. Write a function `cbrt()` that takes an integer $n$ and return $\sqrt[3]{n}$ (cube root of $n$ without using any built in python functionality.

# %%
# Write your code/answer here:

# %% [markdown]
# 2. Write a function `factorial(n)` that computes the factorial of a number `n` using recursion. Then use this function to compute the factorial of 12.
# Note: The factorial of a number $n$ is defined as:
#
# $$ n! = n \cdot (n-1)\cdot (n-2)\cdots 2\cdot 1$$

# %%
# Write your code/answer here:

# %% [markdown]
# 3. Create a function `fibonacci(n)` that returns the first `n` numbers in the Fibonacci sequence using iteration (not recursion).

# %%
# Write your code/answer here:

# %% [markdown]
# 4. Write a function `is_anagram(s1, s2)` that returns `True` if the two input strings are anagrams of each other (case-insensitive, ignoring spaces), otherwise returns `False`.

# %%
# Write your code/answer here:

# %% [markdown]
# 5.

# %% [markdown]
# ---
#
# ### **End of Question Paper**
#
# Thank you for attempting the assignment!
# Double check your answers and ensure your code is tested and well-indented.
#
#  **Note:** Submit your completed scripts or notebook before the 8th of July 2025.
#
#  **Good Luck!**
#
# ---
